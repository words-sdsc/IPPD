# %%
# import all the filenames
from allfunctions import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 7  def SVRSigmoidCVModel(filename):
#
# 8 def SVRRbfCVModel(filename):

# %%
def wrapper(functionList = []):
    if __name__ == '__main__':
        global model_selection
        global filenames
        
        filenames = ['ABC.pickle', 'BCD.pickle', 'CDA.pickle', 'DAB.pickle' ]
        
        model_selection = {}
        
        for f in functionList:
            print()
            for filename in filenames:
                print('function = %s, filename = %s' % (f,filename))
                out = f(filename)
                newScore = out[filename]['train_rmse_cv_picking']

                if filename in model_selection:
                    #compare scores and select more accurate model
                    oldScore = model_selection[filename]['train_rmse_cv_picking']
                    if(newScore < oldScore):
                        print("【【【】】】switching models for %s..." % filename)
                        print("【【【】】】newScore: %f < oldScore: %f" % (newScore, oldScore))
                        print("【【【】】】newModel: %s \n" % f)
                        print(100*'_')
                        model_selection[filename] = out[filename]
                else:
                    #no score to compare
                    print("【【】】adding new model for %s \n" % filename)
                    print(100*'_')
                    model_selection[filename] = out[filename]
    return model_selection

# %% [markdown]
# # Sigmoid Kernel

# %%
t_SVRSigmoidCVModel = wrapper([ SVRSigmoidCVModel ])
# Out:
# function = <function SVRSigmoidCVModel at 0x7f8eead9c488>, filename = ABC.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 224 and test 97
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='sigmoid', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 97
# array([  746.49,  1959.63,   216.12,  1031.47,   462.77,  2239.73,
#          198.71,   801.4 ,  2470.53,   199.09,  2230.04,  1018.55,
#          218.82,  1806.17,  1634.05,   810.75,   464.01,   460.34,
#          198.88,  2436.08,  1467.65,  1037.18,  1944.16,   750.28,
#          748.82,   504.45,  2478.78,  2241.22,  1792.62,  1141.32,
#          505.67,   510.55,   823.05,  2258.66,   738.16,   503.73,
#         2125.54,  1273.42,  2142.12,  1799.43,   747.33,  1801.74,
#         1802.26,  2119.13,  1332.56,  2106.02,   214.64,  1459.44,
#         1627.26,  1139.61,  1623.84,  1036.77,  2442.42,   216.71,
#         2450.37,   462.06,  2433.27,  1476.76,   813.15,   504.63,
#         1037.79,  1134.68,   460.82,  1808.07,  1467.78,  1135.84,
#          504.92,   215.55,  1471.89,   801.59,  1135.23,  1324.9 ,
#         1637.05,  1462.69,   814.27,  1628.58,  2262.51,  2123.49,
#         1929.21,  2453.84,  1862.39,   216.58,   198.28,  1333.76,
#          720.7 ,  1469.66,   197.88,  1925.99,  2129.21,   503.45,
#         1780.16,   198.45,  1036.27,  1146.09,  2457.56,  2127.71,  1333.42])
# array([ 1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87])
# D: 97
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([  746.49,  1959.63,   216.12,  1031.47,   462.77,  2239.73,
#          198.71,   801.4 ,  2470.53,   199.09,  2230.04,  1018.55,
#          218.82,  1806.17,  1634.05,   810.75,   464.01,   460.34,
#          198.88,  2436.08,  1467.65,  1037.18,  1944.16,   750.28,
#          748.82,   504.45,  2478.78,  2241.22,  1792.62,  1141.32,
#          505.67,   510.55,   823.05,  2258.66,   738.16,   503.73,
#         2125.54,  1273.42,  2142.12,  1799.43,   747.33,  1801.74,
#         1802.26,  2119.13,  1332.56,  2106.02,   214.64,  1459.44,
#         1627.26,  1139.61,  1623.84,  1036.77,  2442.42,   216.71,
#         2450.37,   462.06,  2433.27,  1476.76,   813.15,   504.63,
#         1037.79,  1134.68,   460.82,  1808.07,  1467.78,  1135.84,
#          504.92,   215.55,  1471.89,   801.59,  1135.23,  1324.9 ,
#         1637.05,  1462.69,   814.27,  1628.58,  2262.51,  2123.49,
#         1929.21,  2453.84,  1862.39,   216.58,   198.28,  1333.76,
#          720.7 ,  1469.66,   197.88,  1925.99,  2129.21,   503.45,
#         1780.16,   198.45,  1036.27,  1146.09,  2457.56,  2127.71,  1333.42])
# array([ 1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,
#         1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87,  1859.87])
# 【【】】adding new model for ABC.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRSigmoidCVModel at 0x7f8eead9c488>, filename = BCD.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 289 and test 32
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='sigmoid', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 32
# array([ 203.5 ,  142.31,  121.17,   97.83,   21.58,  164.02,  164.88,
#          67.96,   98.42,  120.19,  141.66,   98.47,   67.97,  204.44,
#          45.97,   45.94,  173.64,  120.44,  203.98,  142.07,  141.54,
#          21.8 ,   46.36,   68.75,   97.49,  120.67,  166.8 ,   45.82,
#          21.63,   68.63,   21.6 ,  204.8 ])
# array([ 1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62])
# A: 32
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([ 203.5 ,  142.31,  121.17,   97.83,   21.58,  164.02,  164.88,
#          67.96,   98.42,  120.19,  141.66,   98.47,   67.97,  204.44,
#          45.97,   45.94,  173.64,  120.44,  203.98,  142.07,  141.54,
#          21.8 ,   46.36,   68.75,   97.49,  120.67,  166.8 ,   45.82,
#          21.63,   68.63,   21.6 ,  204.8 ])
# array([ 1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62,  1792.62,  1792.62,  1792.62,  1792.62,
#         1792.62,  1792.62])
# 【【】】adding new model for BCD.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRSigmoidCVModel at 0x7f8eead9c488>, filename = CDA.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 226 and test 95
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='sigmoid', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 95
# array([ 2213.16,  2607.84,  3167.66,  3153.06,  2746.73,  2201.04,
#         1329.19,  1338.01,  1723.63,  2314.1 ,  1332.03,  2006.73,
#         1425.64,  3353.35,  2293.62,  1914.93,  4234.26,  3309.8 ,
#         1846.6 ,  1323.62,  2110.94,  3034.04,  1445.01,  2657.91,
#         3336.48,  3444.3 ,  2472.15,  1616.34,  1740.7 ,  2000.17,
#         2181.44,  3040.59,  2396.68,  2754.95,  2877.71,  3450.94,
#         3357.03,  1732.64,  3168.1 ,  1932.2 ,  1423.13,  2587.3 ,
#         2896.76,  3344.01,  1174.9 ,  2855.36,  2752.13,  2024.25,
#         2661.74,  2130.06,  1861.97,  1578.23,  3152.83,  2544.55,
#         2474.21,  1621.36,  1620.72,  2210.97,  2376.19,  2308.37,
#         3028.27,  2001.65,  2896.27,  3055.04,  1447.46,  1583.26,
#         3348.91,  2586.27,  1331.2 ,  1393.36,  3186.2 ,  3359.25,
#         3371.75,  3192.92,  1895.33,  1632.23,  2461.26,  2940.97,
#         1320.38,  3077.01,  1315.75,  2769.22,  1721.38,  2486.13,
#         1919.57,  3186.16,  2306.07,  2179.65,  2511.62,  3049.37,
#         2397.91,  2762.97,  1623.2 ,  2184.34,  1593.28])
# array([ 1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725])
# B: 95
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([ 2213.16,  2607.84,  3167.66,  3153.06,  2746.73,  2201.04,
#         1329.19,  1338.01,  1723.63,  2314.1 ,  1332.03,  2006.73,
#         1425.64,  3353.35,  2293.62,  1914.93,  4234.26,  3309.8 ,
#         1846.6 ,  1323.62,  2110.94,  3034.04,  1445.01,  2657.91,
#         3336.48,  3444.3 ,  2472.15,  1616.34,  1740.7 ,  2000.17,
#         2181.44,  3040.59,  2396.68,  2754.95,  2877.71,  3450.94,
#         3357.03,  1732.64,  3168.1 ,  1932.2 ,  1423.13,  2587.3 ,
#         2896.76,  3344.01,  1174.9 ,  2855.36,  2752.13,  2024.25,
#         2661.74,  2130.06,  1861.97,  1578.23,  3152.83,  2544.55,
#         2474.21,  1621.36,  1620.72,  2210.97,  2376.19,  2308.37,
#         3028.27,  2001.65,  2896.27,  3055.04,  1447.46,  1583.26,
#         3348.91,  2586.27,  1331.2 ,  1393.36,  3186.2 ,  3359.25,
#         3371.75,  3192.92,  1895.33,  1632.23,  2461.26,  2940.97,
#         1320.38,  3077.01,  1315.75,  2769.22,  1721.38,  2486.13,
#         1919.57,  3186.16,  2306.07,  2179.65,  2511.62,  3049.37,
#         2397.91,  2762.97,  1623.2 ,  2184.34,  1593.28])
# array([ 1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725,  1137.725,
#         1137.725,  1137.725,  1137.725,  1137.725,  1137.725])
# 【【】】adding new model for CDA.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRSigmoidCVModel at 0x7f8eead9c488>, filename = DAB.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 224 and test 97
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='sigmoid', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 97
# array([  299.12,   297.65,  2271.12,  1870.14,   976.5 ,  1357.24,
#          320.75,  3085.44,  1073.56,  1688.66,  1366.43,  1728.17,
#         1365.13,  2674.81,  2294.56,   639.5 ,  2684.27,  2671.47,
#         2087.18,   297.21,  1869.08,  1364.75,  2089.36,  1881.93,
#         3621.04,   998.65,  1083.5 ,  3055.04,  2828.23,  2265.29,
#         1470.8 ,   322.13,   695.76,   643.53,  3326.93,   322.27,
#          323.32,   298.64,  2844.98,   640.49,  1724.47,  2675.11,
#         3090.73,   692.62,  1076.1 ,   298.03,  1082.16,  2270.37,
#         2659.86,   691.73,  2083.07,  2832.66,  2096.62,  2771.25,
#          643.1 ,  1873.73,  1458.18,  2084.72,  2392.64,  2543.24,
#          996.42,  1474.68,   998.83,   300.32,  3143.72,  1087.87,
#         3200.82,  1359.58,  2683.3 ,  2274.86,  3059.32,   323.21,
#         1688.15,  2451.8 ,  1001.19,  2450.48,  1727.59,  1868.49,
#         2832.93,   693.29,   695.31,  1000.24,  1080.  ,  1722.37,
#         1472.6 ,  2441.62,  1857.77,  1879.75,  1466.25,  2833.87,
#         2681.79,   644.52,   689.4 ,   321.59,   697.69,  1358.2 ,  2836.53])
# array([ 1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52])
# C: 97
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([  299.12,   297.65,  2271.12,  1870.14,   976.5 ,  1357.24,
#          320.75,  3085.44,  1073.56,  1688.66,  1366.43,  1728.17,
#         1365.13,  2674.81,  2294.56,   639.5 ,  2684.27,  2671.47,
#         2087.18,   297.21,  1869.08,  1364.75,  2089.36,  1881.93,
#         3621.04,   998.65,  1083.5 ,  3055.04,  2828.23,  2265.29,
#         1470.8 ,   322.13,   695.76,   643.53,  3326.93,   322.27,
#          323.32,   298.64,  2844.98,   640.49,  1724.47,  2675.11,
#         3090.73,   692.62,  1076.1 ,   298.03,  1082.16,  2270.37,
#         2659.86,   691.73,  2083.07,  2832.66,  2096.62,  2771.25,
#          643.1 ,  1873.73,  1458.18,  2084.72,  2392.64,  2543.24,
#          996.42,  1474.68,   998.83,   300.32,  3143.72,  1087.87,
#         3200.82,  1359.58,  2683.3 ,  2274.86,  3059.32,   323.21,
#         1688.15,  2451.8 ,  1001.19,  2450.48,  1727.59,  1868.49,
#         2832.93,   693.29,   695.31,  1000.24,  1080.  ,  1722.37,
#         1472.6 ,  2441.62,  1857.77,  1879.75,  1466.25,  2833.87,
#         2681.79,   644.52,   689.4 ,   321.59,   697.69,  1358.2 ,  2836.53])
# array([ 1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,
#         1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52,  1623.52])
# 【【】】adding new model for DAB.pickle
#
# ____________________________________________________________________________________________________

# %%
t_print = t_SVRSigmoidCVModel

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')
# Out:
# ________________________________________________________________________________
# ABC.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 1131751.987465
#
# D...TestD RMSE   : 928.441271
# D...<<y_test_D Mean>>: 1274.728557
# ________________________________________________________________________________
# ________________________________________________________________________________
# DAB.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 1061969.122770
#
# C...TestC RMSE   : 915.818629
# C...<<y_test_C Mean>>: 1663.210000
#
# ________________________________________________________________________________
# ________________________________________________________________________________
# CDA.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 899220.828855
#
# B...TestB RMSE   : 1413.672614
# B...<<y_test_B Mean>>: 2371.578632
#
# ________________________________________________________________________________
# ________________________________________________________________________________
# BCD.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 828405.615650
#
# A...TestA RMSE   : 1685.113712
# A...<<y_test_A Mean>>: 108.510312
#
# ________________________________________________________________________________

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_SVRSigmoidCVModel
prefix = '4C3_' + 'SVRSigmoidCVModel'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:3]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)
# Out:
# ABC.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRSigmoidCVModel_tuned_ABC.pickle
#
# DAB.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRSigmoidCVModel_tuned_DAB.pickle
#
# CDA.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRSigmoidCVModel_tuned_CDA.pickle
#
# BCD.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRSigmoidCVModel_tuned_BCD.pickle

# %% [markdown]
# # Linear Kernel

# %%
t_SVRLinearCVModel = wrapper([ SVRLinearCVModel ])
# Out:
# function = <function SVRLinearCVModel at 0x7f8eead9c510>, filename = ABC.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 224 and test 97
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
#  Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='linear', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 97
# array([  746.49,  1959.63,   216.12,  1031.47,   462.77,  2239.73,
#          198.71,   801.4 ,  2470.53,   199.09,  2230.04,  1018.55,
#          218.82,  1806.17,  1634.05,   810.75,   464.01,   460.34,
#          198.88,  2436.08,  1467.65,  1037.18,  1944.16,   750.28,
#          748.82,   504.45,  2478.78,  2241.22,  1792.62,  1141.32,
#          505.67,   510.55,   823.05,  2258.66,   738.16,   503.73,
#         2125.54,  1273.42,  2142.12,  1799.43,   747.33,  1801.74,
#         1802.26,  2119.13,  1332.56,  2106.02,   214.64,  1459.44,
#         1627.26,  1139.61,  1623.84,  1036.77,  2442.42,   216.71,
#         2450.37,   462.06,  2433.27,  1476.76,   813.15,   504.63,
#         1037.79,  1134.68,   460.82,  1808.07,  1467.78,  1135.84,
#          504.92,   215.55,  1471.89,   801.59,  1135.23,  1324.9 ,
#         1637.05,  1462.69,   814.27,  1628.58,  2262.51,  2123.49,
#         1929.21,  2453.84,  1862.39,   216.58,   198.28,  1333.76,
#          720.7 ,  1469.66,   197.88,  1925.99,  2129.21,   503.45,
#         1780.16,   198.45,  1036.27,  1146.09,  2457.56,  2127.71,  1333.42])
# array([ 1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000012,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000011,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000011])
# D: 97
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([  746.49,  1959.63,   216.12,  1031.47,   462.77,  2239.73,
#          198.71,   801.4 ,  2470.53,   199.09,  2230.04,  1018.55,
#          218.82,  1806.17,  1634.05,   810.75,   464.01,   460.34,
#          198.88,  2436.08,  1467.65,  1037.18,  1944.16,   750.28,
#          748.82,   504.45,  2478.78,  2241.22,  1792.62,  1141.32,
#          505.67,   510.55,   823.05,  2258.66,   738.16,   503.73,
#         2125.54,  1273.42,  2142.12,  1799.43,   747.33,  1801.74,
#         1802.26,  2119.13,  1332.56,  2106.02,   214.64,  1459.44,
#         1627.26,  1139.61,  1623.84,  1036.77,  2442.42,   216.71,
#         2450.37,   462.06,  2433.27,  1476.76,   813.15,   504.63,
#         1037.79,  1134.68,   460.82,  1808.07,  1467.78,  1135.84,
#          504.92,   215.55,  1471.89,   801.59,  1135.23,  1324.9 ,
#         1637.05,  1462.69,   814.27,  1628.58,  2262.51,  2123.49,
#         1929.21,  2453.84,  1862.39,   216.58,   198.28,  1333.76,
#          720.7 ,  1469.66,   197.88,  1925.99,  2129.21,   503.45,
#         1780.16,   198.45,  1036.27,  1146.09,  2457.56,  2127.71,  1333.42])
# array([ 1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000012,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000011,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000012,  1859.87000012,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000011,  1859.87000011,
#         1859.87000011,  1859.87000012,  1859.87000011,  1859.87000012,
#         1859.87000012,  1859.87000011,  1859.87000012,  1859.87000011,
#         1859.87000011,  1859.87000011,  1859.87000012,  1859.87000012,
#         1859.87000011])
# 【【】】adding new model for ABC.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRLinearCVModel at 0x7f8eead9c510>, filename = BCD.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 289 and test 32
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
#  Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='linear', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 32
# array([ 203.5 ,  142.31,  121.17,   97.83,   21.58,  164.02,  164.88,
#          67.96,   98.42,  120.19,  141.66,   98.47,   67.97,  204.44,
#          45.97,   45.94,  173.64,  120.44,  203.98,  142.07,  141.54,
#          21.8 ,   46.36,   68.75,   97.49,  120.67,  166.8 ,   45.82,
#          21.63,   68.63,   21.6 ,  204.8 ])
# array([ 1792.62000005,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000005,  1792.62000005,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000005,  1792.62000004,  1792.62000004,
#         1792.62000005,  1792.62000004,  1792.62000005,  1792.62000005,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000005,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000005])
# A: 32
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([ 203.5 ,  142.31,  121.17,   97.83,   21.58,  164.02,  164.88,
#          67.96,   98.42,  120.19,  141.66,   98.47,   67.97,  204.44,
#          45.97,   45.94,  173.64,  120.44,  203.98,  142.07,  141.54,
#          21.8 ,   46.36,   68.75,   97.49,  120.67,  166.8 ,   45.82,
#          21.63,   68.63,   21.6 ,  204.8 ])
# array([ 1792.62000005,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000005,  1792.62000005,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000005,  1792.62000004,  1792.62000004,
#         1792.62000005,  1792.62000004,  1792.62000005,  1792.62000005,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000005,  1792.62000004,
#         1792.62000004,  1792.62000004,  1792.62000004,  1792.62000005])
# 【【】】adding new model for BCD.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRLinearCVModel at 0x7f8eead9c510>, filename = CDA.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 226 and test 95
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
#  Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='linear', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 95
# array([ 2213.16,  2607.84,  3167.66,  3153.06,  2746.73,  2201.04,
#         1329.19,  1338.01,  1723.63,  2314.1 ,  1332.03,  2006.73,
#         1425.64,  3353.35,  2293.62,  1914.93,  4234.26,  3309.8 ,
#         1846.6 ,  1323.62,  2110.94,  3034.04,  1445.01,  2657.91,
#         3336.48,  3444.3 ,  2472.15,  1616.34,  1740.7 ,  2000.17,
#         2181.44,  3040.59,  2396.68,  2754.95,  2877.71,  3450.94,
#         3357.03,  1732.64,  3168.1 ,  1932.2 ,  1423.13,  2587.3 ,
#         2896.76,  3344.01,  1174.9 ,  2855.36,  2752.13,  2024.25,
#         2661.74,  2130.06,  1861.97,  1578.23,  3152.83,  2544.55,
#         2474.21,  1621.36,  1620.72,  2210.97,  2376.19,  2308.37,
#         3028.27,  2001.65,  2896.27,  3055.04,  1447.46,  1583.26,
#         3348.91,  2586.27,  1331.2 ,  1393.36,  3186.2 ,  3359.25,
#         3371.75,  3192.92,  1895.33,  1632.23,  2461.26,  2940.97,
#         1320.38,  3077.01,  1315.75,  2769.22,  1721.38,  2486.13,
#         1919.57,  3186.16,  2306.07,  2179.65,  2511.62,  3049.37,
#         2397.91,  2762.97,  1623.2 ,  2184.34,  1593.28])
# array([ 1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993])
# B: 95
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([ 2213.16,  2607.84,  3167.66,  3153.06,  2746.73,  2201.04,
#         1329.19,  1338.01,  1723.63,  2314.1 ,  1332.03,  2006.73,
#         1425.64,  3353.35,  2293.62,  1914.93,  4234.26,  3309.8 ,
#         1846.6 ,  1323.62,  2110.94,  3034.04,  1445.01,  2657.91,
#         3336.48,  3444.3 ,  2472.15,  1616.34,  1740.7 ,  2000.17,
#         2181.44,  3040.59,  2396.68,  2754.95,  2877.71,  3450.94,
#         3357.03,  1732.64,  3168.1 ,  1932.2 ,  1423.13,  2587.3 ,
#         2896.76,  3344.01,  1174.9 ,  2855.36,  2752.13,  2024.25,
#         2661.74,  2130.06,  1861.97,  1578.23,  3152.83,  2544.55,
#         2474.21,  1621.36,  1620.72,  2210.97,  2376.19,  2308.37,
#         3028.27,  2001.65,  2896.27,  3055.04,  1447.46,  1583.26,
#         3348.91,  2586.27,  1331.2 ,  1393.36,  3186.2 ,  3359.25,
#         3371.75,  3192.92,  1895.33,  1632.23,  2461.26,  2940.97,
#         1320.38,  3077.01,  1315.75,  2769.22,  1721.38,  2486.13,
#         1919.57,  3186.16,  2306.07,  2179.65,  2511.62,  3049.37,
#         2397.91,  2762.97,  1623.2 ,  2184.34,  1593.28])
# array([ 1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993,  1137.72499993,
#         1137.72499993,  1137.72499993,  1137.72499993])
# 【【】】adding new model for CDA.pickle
#
# ____________________________________________________________________________________________________
# function = <function SVRLinearCVModel at 0x7f8eead9c510>, filename = DAB.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 224 and test 97
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
#  Best parameters set found on development set:
#
# {'coef0': 1e-10, 'degree': 3, 'epsilon': 1e-08, 'gamma': 9.9999999999999995e-21, 'C': 1e-10}
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degree=3, epsilon=1e-08,
#   gamma=9.9999999999999995e-21, kernel='linear', max_iter=-1,
#   shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 97
# array([  299.12,   297.65,  2271.12,  1870.14,   976.5 ,  1357.24,
#          320.75,  3085.44,  1073.56,  1688.66,  1366.43,  1728.17,
#         1365.13,  2674.81,  2294.56,   639.5 ,  2684.27,  2671.47,
#         2087.18,   297.21,  1869.08,  1364.75,  2089.36,  1881.93,
#         3621.04,   998.65,  1083.5 ,  3055.04,  2828.23,  2265.29,
#         1470.8 ,   322.13,   695.76,   643.53,  3326.93,   322.27,
#          323.32,   298.64,  2844.98,   640.49,  1724.47,  2675.11,
#         3090.73,   692.62,  1076.1 ,   298.03,  1082.16,  2270.37,
#         2659.86,   691.73,  2083.07,  2832.66,  2096.62,  2771.25,
#          643.1 ,  1873.73,  1458.18,  2084.72,  2392.64,  2543.24,
#          996.42,  1474.68,   998.83,   300.32,  3143.72,  1087.87,
#         3200.82,  1359.58,  2683.3 ,  2274.86,  3059.32,   323.21,
#         1688.15,  2451.8 ,  1001.19,  2450.48,  1727.59,  1868.49,
#         2832.93,   693.29,   695.31,  1000.24,  1080.  ,  1722.37,
#         1472.6 ,  2441.62,  1857.77,  1879.75,  1466.25,  2833.87,
#         2681.79,   644.52,   689.4 ,   321.59,   697.69,  1358.2 ,  2836.53])
# array([ 1623.51999188,  1623.51999188,  1623.51999187,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999188,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999188,  1623.51999188,
#         1623.51999187,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999188,
#         1623.51999187])
# C: 97
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
# array([  299.12,   297.65,  2271.12,  1870.14,   976.5 ,  1357.24,
#          320.75,  3085.44,  1073.56,  1688.66,  1366.43,  1728.17,
#         1365.13,  2674.81,  2294.56,   639.5 ,  2684.27,  2671.47,
#         2087.18,   297.21,  1869.08,  1364.75,  2089.36,  1881.93,
#         3621.04,   998.65,  1083.5 ,  3055.04,  2828.23,  2265.29,
#         1470.8 ,   322.13,   695.76,   643.53,  3326.93,   322.27,
#          323.32,   298.64,  2844.98,   640.49,  1724.47,  2675.11,
#         3090.73,   692.62,  1076.1 ,   298.03,  1082.16,  2270.37,
#         2659.86,   691.73,  2083.07,  2832.66,  2096.62,  2771.25,
#          643.1 ,  1873.73,  1458.18,  2084.72,  2392.64,  2543.24,
#          996.42,  1474.68,   998.83,   300.32,  3143.72,  1087.87,
#         3200.82,  1359.58,  2683.3 ,  2274.86,  3059.32,   323.21,
#         1688.15,  2451.8 ,  1001.19,  2450.48,  1727.59,  1868.49,
#         2832.93,   693.29,   695.31,  1000.24,  1080.  ,  1722.37,
#         1472.6 ,  2441.62,  1857.77,  1879.75,  1466.25,  2833.87,
#         2681.79,   644.52,   689.4 ,   321.59,   697.69,  1358.2 ,  2836.53])
# array([ 1623.51999188,  1623.51999188,  1623.51999187,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999188,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999188,  1623.51999187,  1623.51999188,  1623.51999188,
#         1623.51999187,  1623.51999188,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999187,  1623.51999187,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999187,
#         1623.51999187,  1623.51999187,  1623.51999187,  1623.51999188,
#         1623.51999188,  1623.51999188,  1623.51999188,  1623.51999188,
#         1623.51999187])
# 【【】】adding new model for DAB.pickle
#
# ____________________________________________________________________________________________________

# %%
t_print = t_SVRLinearCVModel

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')
# Out:
# ________________________________________________________________________________
# ABC.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 1131751.987448
#
# D...TestD RMSE   : 928.441271
# D...<<y_test_D Mean>>: 1274.728557
# ________________________________________________________________________________
# ________________________________________________________________________________
# DAB.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 1061969.122381
#
# C...TestC RMSE   : 915.818629
# C...<<y_test_C Mean>>: 1663.210000
#
# ________________________________________________________________________________
# ________________________________________________________________________________
# CDA.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 899220.828738
#
# B...TestB RMSE   : 1413.672614
# B...<<y_test_B Mean>>: 2371.578632
#
# ________________________________________________________________________________
# ________________________________________________________________________________
# BCD.pickle
# Model: SVR(C=1e-10, cache_s
# Train RMSE: 828405.615628
#
# A...TestA RMSE   : 1685.113712
# A...<<y_test_A Mean>>: 108.510312
#
# ________________________________________________________________________________

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_SVRLinearCVModel
prefix = '4C3_' + 'SVRLinearCVModel'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:3]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)
# Out:
# ABC.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRLinearCVModel_tuned_ABC.pickle
#
# DAB.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRLinearCVModel_tuned_DAB.pickle
#
# CDA.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRLinearCVModel_tuned_CDA.pickle
#
# BCD.pickle SVR(C=1e-10, cache_size=204800
# 4C3_SVRLinearCVModel_tuned_BCD.pickle

# %% [markdown]
# # rbf Kernel

# %%
t_SVRRbfCVModel = wrapper([ SVRRbfCVModel ])

# %%
t_print = t_SVRRbfCVModel

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:200]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_SVRRbfCVModel
prefix = '4C3_' + 'SVRRbfCVModel'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:3]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Poly Kernel

# %%
t_SVRPolyCVModel = wrapper([ SVRPolyCVModel ])
# Out:
# function = <function SVRPolyCVModel at 0x7f8eead9c400>, filename = ABC.pickle
#
# {{ scale_this: >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Scaling X_train and X_test... }}
#
# Dataset size read: train 224 and test 97
#
# # Tuning hyper-parameters...
#
# Starting grdsurch.fit(X_train, y_train)

# %%
t_print = t_SVRPolyCVModel

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_SVRPolyCVModel
prefix = '4C3_' + 'SVRPolyCVModel'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:3]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Which features were given most weights by each model ?
