# %%
import pandas as pd

# %%
def update_importance(features_dict, kee, file_name, feat_imp, make_positive=False ):
    import pickle
    import copy

    
    # use 'key i.e. kee' to get the right dataframe
    df = features_dict[kee]
    
    # append a new column to the dataframe
    if(len(feat_imp) == 1):
        feat_imp = feat_imp[0]
    
    print('length of col vector : %d' % len(feat_imp))
    
    if (make_positive):
        print('making positive ...')
        pos = [ abs(x) for x in feat_imp ]
        feat_imp = pos
        
    df[file_name[:-7]] = copy.deepcopy(feat_imp)
    
    print(df.columns.values.tolist())

# %%
feature_imp = {}
feature_imp['4c4']=pd.DataFrame()
feature_imp['4c3']=pd.DataFrame()
feature_imp['4c2']=pd.DataFrame()

# %%
#write to disk
import pickle

with open('feature_importance.pkl', 'wb') as output:
    pickle.dump(feature_imp, output, pickle.HIGHEST_PROTOCOL)

# %%
#load from disk
with open('feature_importance.pkl', 'rb') as input:
    features_dict = pickle.load(input)

# %%
abs(-1)
# Out:
# 1

# %%
def fill_dict(files, kee):
    import pickle 
    global features_dict

    for fname in files:
        with open(fname, 'rb') as input:
            model = pickle.load(input)
            model_name = str(model)[:50]
            try:
                try:
                    x = len(model.feature_importances_)
                    print(model_name)
                    print('model.feature_importances_ with len = %d' % x)
                    #print(model.feature_importances_)
                    update_importance(features_dict, kee, fname, model.feature_importances_, False)
                except Exception as a:
                    #print('error ... %s' % a)
                    pass
            
                try:
                    y = len(model.coef_)
                    print(model_name)
                    print('model.coef_ with len = %d' % y)
                    #print(y)
                    update_importance(features_dict, kee, fname, model.coef_, True)
                except Exception as b:
                    #print('error...%s' % b)
                    pass
            except:
                pass
            print(60*'_')

# %%
import os

# %% [markdown]
# ##################

# %%
#########################
kee = '4c4'
#########################

partition = kee.upper()
files = [f for f in os.listdir('.') if (os.path.isfile(f) and partition in f and 'tuned' in f)]

# %%
files
# Out:
# ['4C4_lasso_tuned_ABCD.pickle',
#  '4C4_SVRPolyCVModel_tuned_ABCD.pickle',
#  '4C4_SVRSigmoidCVModel_tuned_ABCD.pickle',
#  '4C4_elasticNet_tuned_ABCD.pickle',
#  '4C4_SVRRbfCVModel_tuned_ABCD.pickle',
#  '4C4_SVRLinearCVModel_tuned_ABCD.pickle',
#  '4C4_gb_tuned_ABCD.pickle',
#  '4C4_ridge_tuned_ABCD.pickle',
#  '4C4_rf_tuned_ABCD.pickle']

# %%
fill_dict(files, kee)
# Out:
# Lasso(alpha=0.019306977288832496, copy_X=True, fit
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C4_lasso_tuned_ABCD']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# ElasticNet(alpha=8.8862381627434068e-08, copy_X=Tr
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C4_lasso_tuned_ABCD', '4C4_elasticNet_tuned_ABCD']
# ____________________________________________________________
# ____________________________________________________________
# SVR(C=1.0, cache_size=204800, coef0=1e-10, degree=
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C4_lasso_tuned_ABCD', '4C4_elasticNet_tuned_ABCD', '4C4_SVRLinearCVModel_tuned_ABCD']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C4_lasso_tuned_ABCD', '4C4_elasticNet_tuned_ABCD', '4C4_SVRLinearCVModel_tuned_ABCD', '4C4_gb_tuned_ABCD']
# ____________________________________________________________
# Ridge(alpha=1e-35, copy_X=True, fit_intercept=True
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C4_lasso_tuned_ABCD', '4C4_elasticNet_tuned_ABCD', '4C4_SVRLinearCVModel_tuned_ABCD', '4C4_gb_tuned_ABCD', '4C4_ridge_tuned_ABCD']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C4_lasso_tuned_ABCD', '4C4_elasticNet_tuned_ABCD', '4C4_SVRLinearCVModel_tuned_ABCD', '4C4_gb_tuned_ABCD', '4C4_ridge_tuned_ABCD', '4C4_rf_tuned_ABCD']
# ____________________________________________________________

# %%
for g in features_dict.keys():
    print(g, features_dict[g].shape)
# Out:
# 4c4 (57, 6)
# 4c3 (0, 0)
# 4c2 (0, 0)

# %% [markdown]
# ##################

# %%
#########################
kee = '4c3'
#########################

partition = kee.upper()
files = [f for f in os.listdir('.') if (os.path.isfile(f) and partition in f and 'tuned' in f)]

# %%
files
# Out:
# ['4C3_SVRPolyCVModel_tuned_BCD.pickle',
#  '4C3_SVRRbfCVModel_tuned_DAB.pickle',
#  '4C3_ridge_tuned_ABC.pickle',
#  '4C3_rf_tuned_DAB.pickle',
#  '4C3_SVRSigmoidCVModel_tuned_ABC.pickle',
#  '4C3_rf_tuned_CDA.pickle',
#  '4C3_SVRRbfCVModel_tuned_ABC.pickle',
#  '4C3_SVRPolyCVModel_tuned_DAB.pickle',
#  '4C3_SVRRbfCVModel_tuned_BCD.pickle',
#  '4C3_SVRLinearCVModel_tuned_CDA.pickle',
#  '4C3_elasticNet_tuned_BCD.pickle',
#  '4C3_SVRLinearCVModel_tuned_DAB.pickle',
#  '4C3_lasso_tuned_CDA.pickle',
#  '4C3_rf_tuned_ABC.pickle',
#  '4C3_SVRPolyCVModel_tuned_CDA.pickle',
#  '4C3_SVRLinearCVModel_tuned_BCD.pickle',
#  '4C3_elasticNet_tuned_ABC.pickle',
#  '4C3_SVRSigmoidCVModel_tuned_CDA.pickle',
#  '4C3_lasso_tuned_BCD.pickle',
#  '4C3_ridge_tuned_DAB.pickle',
#  '4C3_gb_tuned_CDA.pickle',
#  '4C3_lasso_tuned_DAB.pickle',
#  '4C3_elasticNet_tuned_CDA.pickle',
#  '4C3_elasticNet_tuned_DAB.pickle',
#  '4C3_gb_tuned_BCD.pickle',
#  '4C3_SVRRbfCVModel_tuned_CDA.pickle',
#  '4C3_SVRPolyCVModel_tuned_ABC.pickle',
#  '4C3_lasso_tuned_ABC.pickle',
#  '4C3_SVRLinearCVModel_tuned_ABC.pickle',
#  '4C3_SVRSigmoidCVModel_tuned_DAB.pickle',
#  '4C3_ridge_tuned_BCD.pickle',
#  '4C3_gb_tuned_DAB.pickle',
#  '4C3_gb_tuned_ABC.pickle',
#  '4C3_SVRSigmoidCVModel_tuned_BCD.pickle',
#  '4C3_ridge_tuned_CDA.pickle',
#  '4C3_rf_tuned_BCD.pickle']

# %%
fill_dict(files, kee)
# Out:
# ____________________________________________________________
# ____________________________________________________________
# Ridge(alpha=8.6974900261777992e+18, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB']
# ____________________________________________________________
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB']
# ____________________________________________________________
# Lasso(alpha=1389.4954943731361, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC']
# ____________________________________________________________
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC']
# ____________________________________________________________
# ____________________________________________________________
# Lasso(alpha=719.68567300115137, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD']
# ____________________________________________________________
# Ridge(alpha=1.4174741629268192e+20, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA']
# ____________________________________________________________
# Lasso(alpha=1389.4954943731361, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# Lasso(alpha=719.68567300115137, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC']
# ____________________________________________________________
# ____________________________________________________________
# Ridge(alpha=8.6974900261777992e+18, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC', '4C3_ridge_tuned_BCD']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC', '4C3_ridge_tuned_BCD', '4C3_gb_tuned_DAB']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC', '4C3_ridge_tuned_BCD', '4C3_gb_tuned_DAB', '4C3_gb_tuned_ABC']
# ____________________________________________________________
# ____________________________________________________________
# Ridge(alpha=3.5111917342151418e+19, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC', '4C3_ridge_tuned_BCD', '4C3_gb_tuned_DAB', '4C3_gb_tuned_ABC', '4C3_ridge_tuned_CDA']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C3_ridge_tuned_ABC', '4C3_rf_tuned_DAB', '4C3_rf_tuned_CDA', '4C3_SVRLinearCVModel_tuned_CDA', '4C3_elasticNet_tuned_BCD', '4C3_SVRLinearCVModel_tuned_DAB', '4C3_lasso_tuned_CDA', '4C3_rf_tuned_ABC', '4C3_SVRLinearCVModel_tuned_BCD', '4C3_elasticNet_tuned_ABC', '4C3_lasso_tuned_BCD', '4C3_ridge_tuned_DAB', '4C3_gb_tuned_CDA', '4C3_lasso_tuned_DAB', '4C3_elasticNet_tuned_CDA', '4C3_elasticNet_tuned_DAB', '4C3_gb_tuned_BCD', '4C3_lasso_tuned_ABC', '4C3_SVRLinearCVModel_tuned_ABC', '4C3_ridge_tuned_BCD', '4C3_gb_tuned_DAB', '4C3_gb_tuned_ABC', '4C3_ridge_tuned_CDA', '4C3_rf_tuned_BCD']
# ____________________________________________________________

# %%
for g in features_dict.keys():
    print(g, features_dict[g].shape)
# Out:
# 4c4 (57, 6)
# 4c3 (57, 24)
# 4c2 (0, 0)

# %% [markdown]
# ##################

# %%
#########################
kee = '4c2'
#########################

partition = kee.upper()
files = [f for f in os.listdir('.') if (os.path.isfile(f) and partition in f and 'tuned' in f)]

# %%
files
# Out:
# ['4C2_SVRPolyCVModel_tuned_CD.pickle',
#  '4C2_SVRPolyCVModel_tuned_BD.pickle',
#  '4C2_lasso_tuned_AD.pickle',
#  '4C2_svr_sig_tuned_AC.pickle',
#  '4C2_elasticNet_tuned_BD.pickle',
#  '4C2_svr_sig_tuned_BD.pickle',
#  '4C2_SVRRbfCVModel_tuned_AB.pickle',
#  '4C2_svr_sig_tuned_AD.pickle',
#  '4C2_ridge_tuned_AB.pickle',
#  '4C2_SVRRbfCVModel_tuned_BD.pickle',
#  '4C2_SVRLinearCVModel_tuned_CD.pickle',
#  '4C2_SVRPolyCVModel_tuned_BC.pickle',
#  '4C2_ridge_tuned_AD.pickle',
#  '4C2_SVRLinearCVModel_tuned_AB.pickle',
#  '4C2_svr_sig_tuned_AB.pickle',
#  '4C2_rforest_tuned_AD.pickle',
#  '4C2_rforest_tuned_AB.pickle',
#  '4C2_elasticNet_tuned_BC.pickle',
#  '4C2_SVRLinearCVModel_tuned_BD.pickle',
#  '4C2_SVRLinearCVModel_tuned_AC.pickle',
#  '4C2_elasticNet_tuned_AB.pickle',
#  '4C2_elasticNet_tuned_AC.pickle',
#  '4C2_lasso_tuned_AB.pickle',
#  '4C2_gb_tuned_BD.pickle',
#  '4C2_rforest_tuned_BD.pickle',
#  '4C2_SVRRbfCVModel_tuned_AC.pickle',
#  '4C2_gb_tuned_BC.pickle',
#  '4C2_ridge_tuned_BD.pickle',
#  '4C2_SVRLinearCVModel_tuned_BC.pickle',
#  '4C2_SVRPolyCVModel_tuned_AC.pickle',
#  '4C2_svr_sig_tuned_BC.pickle',
#  '4C2_elasticNet_tuned_AD.pickle',
#  '4C2_SVRRbfCVModel_tuned_BC.pickle',
#  '4C2_SVRRbfCVModel_tuned_AD.pickle',
#  '4C2_gb_tuned_AC.pickle',
#  '4C2_ridge_tuned_BC.pickle',
#  '4C2_SVRRbfCVModel_tuned_CD.pickle',
#  '4C2_gb_tuned_AD.pickle',
#  '4C2_gb_tuned_AB.pickle',
#  '4C2_SVRPolyCVModel_tuned_AD.pickle',
#  '4C2_rforest_tuned_BC.pickle',
#  '4C2_gb_tuned_CD.pickle',
#  '4C2_ridge_tuned_AC.pickle',
#  '4C2_SVRPolyCVModel_tuned_AB.pickle',
#  '4C2_lasso_tuned_BC.pickle',
#  '4C2_lasso_tuned_BD.pickle',
#  '4C2_lasso_tuned_CD.pickle',
#  '4C2_lasso_tuned_AC.pickle',
#  '4C2_svr_sig_tuned_CD.pickle',
#  '4C2_rforest_tuned_AC.pickle',
#  '4C2_elasticNet_tuned_CD.pickle',
#  '4C2_SVRLinearCVModel_tuned_AD.pickle',
#  '4C2_rforest_tuned_CD.pickle',
#  '4C2_ridge_tuned_CD.pickle']

# %%
fill_dict(files, kee)
# Out:
# ____________________________________________________________
# ____________________________________________________________
# Lasso(alpha=719.68567300115137, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD']
# ____________________________________________________________
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# Ridge(alpha=1.4174741629268192e+20, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB']
# ____________________________________________________________
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD']
# ____________________________________________________________
# ____________________________________________________________
# Ridge(alpha=1.7475284000076829e-31, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB']
# ____________________________________________________________
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC']
# ____________________________________________________________
# Lasso(alpha=1389.4954943731361, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD']
# ____________________________________________________________
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC']
# ____________________________________________________________
# Ridge(alpha=3.5111917342151418e+19, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD']
# ____________________________________________________________
# ____________________________________________________________
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC']
# ____________________________________________________________
# Ridge(alpha=2.8480358684357932e-30, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC']
# ____________________________________________________________
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB']
# ____________________________________________________________
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC']
# ____________________________________________________________
# GradientBoostingRegressor(alpha=0.9, criterion='fr
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD']
# ____________________________________________________________
# Ridge(alpha=1.4174741629268192e+20, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC']
# ____________________________________________________________
# ____________________________________________________________
# Lasso(alpha=719.68567300115137, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC']
# ____________________________________________________________
# Lasso(alpha=719.68567300115137, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD']
# ____________________________________________________________
# Lasso(alpha=1389.4954943731361, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD']
# ____________________________________________________________
# Lasso(alpha=1389.4954943731361, copy_X=True, fit_i
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC']
# ____________________________________________________________
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC', '4C2_rforest_tuned_AC']
# ____________________________________________________________
# ElasticNet(alpha=1603.7187437513408, copy_X=True,
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC', '4C2_rforest_tuned_AC', '4C2_elasticNet_tuned_CD']
# ____________________________________________________________
# SVR(C=1e-10, cache_size=204800, coef0=1e-10, degre
# model.coef_ with len = 1
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC', '4C2_rforest_tuned_AC', '4C2_elasticNet_tuned_CD', '4C2_SVRLinearCVModel_tuned_AD']
# ____________________________________________________________
# RandomForestRegressor(bootstrap=True, criterion='m
# model.feature_importances_ with len = 57
# length of col vector : 57
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC', '4C2_rforest_tuned_AC', '4C2_elasticNet_tuned_CD', '4C2_SVRLinearCVModel_tuned_AD', '4C2_rforest_tuned_CD']
# ____________________________________________________________
# Ridge(alpha=3.5111917342151418e+19, copy_X=True, f
# model.coef_ with len = 57
# length of col vector : 57
# making positive ...
# ['4C2_lasso_tuned_AD', '4C2_elasticNet_tuned_BD', '4C2_ridge_tuned_AB', '4C2_SVRLinearCVModel_tuned_CD', '4C2_ridge_tuned_AD', '4C2_SVRLinearCVModel_tuned_AB', '4C2_rforest_tuned_AD', '4C2_rforest_tuned_AB', '4C2_elasticNet_tuned_BC', '4C2_SVRLinearCVModel_tuned_BD', '4C2_SVRLinearCVModel_tuned_AC', '4C2_elasticNet_tuned_AB', '4C2_elasticNet_tuned_AC', '4C2_lasso_tuned_AB', '4C2_gb_tuned_BD', '4C2_rforest_tuned_BD', '4C2_gb_tuned_BC', '4C2_ridge_tuned_BD', '4C2_SVRLinearCVModel_tuned_BC', '4C2_elasticNet_tuned_AD', '4C2_gb_tuned_AC', '4C2_ridge_tuned_BC', '4C2_gb_tuned_AD', '4C2_gb_tuned_AB', '4C2_rforest_tuned_BC', '4C2_gb_tuned_CD', '4C2_ridge_tuned_AC', '4C2_lasso_tuned_BC', '4C2_lasso_tuned_BD', '4C2_lasso_tuned_CD', '4C2_lasso_tuned_AC', '4C2_rforest_tuned_AC', '4C2_elasticNet_tuned_CD', '4C2_SVRLinearCVModel_tuned_AD', '4C2_rforest_tuned_CD', '4C2_ridge_tuned_CD']
# ____________________________________________________________

# %%
for g in features_dict.keys():
    print(g, features_dict[g].shape)
# Out:
# 4c4 (57, 6)
# 4c3 (57, 24)
# 4c2 (57, 36)

# %% [markdown]
# ##################

# %%
# write back to file

with open('feature_importance.pkl', 'wb') as output:
    pickle.dump(feature_imp, output, pickle.HIGHEST_PROTOCOL)

# %%
def plot_heatmap(matx, file_name, fsize=(10,20)):
    import seaborn as sns
    import matplotlib.pyplot as plt
    from sklearn.preprocessing import MinMaxScaler

    # %matplotlib inline

    cols = matx.columns

    matx = MinMaxScaler().fit_transform(matx)
    matx = pd.DataFrame(matx, columns = cols)

    sns.set(context="paper", font="monospace")

    # Set up the matplotlib figure

    f, ax = plt.subplots(figsize=fsize)
    f.tight_layout()
    
    plt.setp(ax.get_xticklabels(), fontsize=10)
    plt.setp(ax.get_yticklabels(), fontsize=10)

    # Draw the heatmap using seaborn
    sns.heatmap(matx, vmax=1.0, square=False, linewidths=.5, center=0.5)
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.savefig(file_name)

# %% [markdown]
# # Plot 4c4

# %%
matx = features_dict['4c4']
plot_heatmap(matx, '4c4featureimportance.png')

# %% [markdown]
# # Plot 4c3

# %%
matx = features_dict['4c3']
plot_heatmap(matx, '4c3_featureimportance.png')

# %% [markdown]
# # Plot 4c2

# %%
matx = features_dict['4c2']
plot_heatmap(matx, '4c2_featureimportance.png', fsize=(15,20))
