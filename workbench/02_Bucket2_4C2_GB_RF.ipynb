# %%
# import all the filenames
from allfunctions import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 3  def GradientBoostingCVModel(filename):
#
# 4  def RandomForestCVModel(filename):

# %%
def wrapper(functionList = []):
    if __name__ == '__main__':
        global model_selection
        global filenames

        # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
        filenames = ['AB.pickle', 'BC.pickle', 'CD.pickle', 'AC.pickle', 'AD.pickle', 'BD.pickle' ]
        # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
        
        model_selection = {}
        
        for f in functionList:
            print()
            for filename in filenames:
                out = f(filename)
                newScore = out[filename]['train_rmse_cv_picking']

                if filename in model_selection:
                    #compare scores and select more accurate model
                    oldScore = model_selection[filename]['train_rmse_cv_picking']
                    if(newScore < oldScore):
                        print("【【【】】】switching models for %s..." % filename)
                        print("【【【】】】newScore: %f < oldScore: %f" % (newScore, oldScore))
                        print("【【【】】】newModel: %s \n" % f)
                        print(100*'_')
                        model_selection[filename] = out[filename]
                else:
                    #no score to compare
                    print("【【】】adding new model for %s \n" % filename)
                    print(100*'_')
                    model_selection[filename] = out[filename]
    return model_selection

# %%
t_gb = wrapper([ GradientBoostingCVModel ])
# Out:
# Dataset size read: train 127 and test 194
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.001, 'loss': 'ls', 'n_estimators': 2000}
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.001, loss='ls', max_depth=None,
#              max_features=None, max_leaf_nodes=None,
#              min_impurity_split=1e-07, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2000, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)
#
# Full Test Set: 194
# array([  297.65,   216.58,   644.52,  2087.18,  1332.56,  1467.65,
#          693.29,  1792.62,  3085.44,   691.73,  2392.64,   323.32,
#         2436.08,  1628.58,   748.82,  2129.21,  2274.86,  1324.9 ,
#          504.92,  2844.98,  2451.8 ,  2457.56,  1471.89,   998.83,
#         3055.04,  3326.93,   738.16,  1073.56,  1799.43,   823.05,
#         1862.39,  2258.66,   746.49,   801.4 ,   747.33,  1879.75,
#         2239.73,  2771.25,  1857.77,  2106.02,  1037.18,  1474.68,
#         1366.43,  2127.71,  1466.25,  1925.99,  1134.68,  2674.81,
#          976.5 ,   464.01,   198.71,   322.13,   510.55,  1135.23,
#         1135.84,   697.69,  1076.1 ,  2683.3 ,   640.49,   750.28,
#          198.88,   643.53,  1364.75,   813.15,   998.65,  2470.53,
#         1365.13,  1881.93,  2241.22,  2265.29,  1472.6 ,   643.1 ,
#         2089.36,   198.45,  2294.56,  1627.26,   505.67,   321.59,
#          695.31,   720.7 ,   692.62,  1808.07,  2442.42,   689.4 ,
#         3059.32,   216.12,  2828.23,   214.64,  2836.53,  3090.73,
#         2450.48,  1031.47,   504.63,  1082.16,  2084.72,  1634.05,
#          320.75,  2478.78,  1806.17,  1273.42,  1868.49,  2230.04,
#         3143.72,  2681.79,   503.73,  2684.27,   504.45,   462.77,
#          215.55,  1870.14,   462.06,  2453.84,  2450.37,  1688.15,
#         1688.66,  2659.86,   814.27,  1037.79,  1722.37,   323.21,
#         3621.04,  1780.16,   460.34,   503.45,  1637.05,  1080.  ,
#         2543.24,  1087.87,   298.64,   996.42,  1959.63,  1728.17,
#         2675.11,  1623.84,  1141.32,   218.82,  2123.49,   810.75,
#         2083.07,  1929.21,  1801.74,  2096.62,  1357.24,  2671.47,
#         1266.78308427,  1253.99419429,  1306.38716022,  1252.51332917,
#         1223.72875271,  1281.16552677,  1309.41716143,  1271.59336658,
#         1328.67175149,  1020.9929218 ,  1288.50219393,  1197.28654953,
#         1239.88808689,  1226.78968654,  1268.03827531,  1281.16552677,
#         1306.38716022,  1284.27054084,  1047.74366366,  1296.51494857,
#         1281.16552677,  1078.15849549,  1227.22614177,  1268.03827531,
#         1183.11488818,  1064.97931206,  1266.78308427,  1108.72335306,
#         1239.88808689])
# 【【】】adding new model for AB.pickle
#
# ____________________________________________________________________________________________________
# Dataset size read: train 192 and test 129
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.001, 'loss': 'ls', 'n_estimators': 2000}
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.001, loss='ls', max_depth=None,
#              max_features=None, max_leaf_nodes=None,
#              min_impurity_split=1e-07, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=2000, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)
#
# Full Test Set: 129
# array([ 1332.56,  1462.69,    45.82,   801.4 ,  2123.49,  1135.23,
#          746.49,  2142.12,   198.45,  2106.02,   198.71,  1806.17,
#         1135.84,  2230.04,   215.55,   141.54,  1037.79,  1467.78,
#           21.6 ,   216.71,  1471.89,   197.88,   505.67,  2127.71,
#         2478.78,   203.98,   747.33,  2129.21,  1792.62,    21.63,
#          120.44,  1959.63,  1802.26,  1134.68,   810.75,  1141.32,
#         2258.66,    45.94,  1944.16,   216.12,   204.44,    21.58,
#           98.42,  2442.42,  1469.66,  1036.27,   204.8 ,    46.36,
#         1623.84,   142.07,  1037.18,  2450.37,    67.96,  1333.76,
#         1036.77,  2453.84,  2241.22,  1780.16,   748.82,  1627.26,
#          460.34,   120.67,   503.45,   504.63,   166.8 ,  1467.65,
#          462.77,   814.27,   720.7 ,   173.64,  1808.07,   216.58,
#         2239.73,   823.05,  1628.58,  2470.53,   142.31,  1634.05,
#         2433.27,    97.49,    21.8 ,    98.47,  2125.54,  1324.9 ,
#          801.59,   738.16,  1476.76,   214.64,   813.15,  1139.61,
#          218.82,  1333.42,  2436.08,  1925.99,  1801.74,  2262.51,
#          199.09,   464.01,    68.75,  1018.55,   504.92,  1862.39,
#          198.88,   120.19,    67.97,  1929.21,    45.97,   198.28,
#          504.45,  1637.05,  1273.42,   462.06,  1459.44,   460.82,
#         2119.13,   503.73,   164.88,   510.55,  1031.47,    97.83,
#          141.66,   203.5 ,   164.02,  2457.56,   121.17,    68.63,
#         1146.09,  1799.43,   750.28])
# array([ 1874.20354866,  2162.30628194,  2595.68647349,  2014.06998743,
#         2279.87701274,  2115.07720306,  1944.99461505,  2342.9978586 ,
#         1856.33077241,  2054.51147603,  1792.13715627,  2342.9978586 ,
#         1874.20354866,  2489.35282452,  1792.13715627,  2805.34195974,
#         1874.20354866,  2171.97352083,  2113.55122031,  1856.33077241,
#         2115.07720306,  1792.13715627,  1549.35249409,  2342.9978586 ,
#         2208.62846267,  2408.78430058,  2018.46168666,  2333.48263302,
#         2342.9978586 ,  2587.4055723 ,  2734.60618752,  2054.51147603,
#         2333.48263302,  2171.97352083,  2018.46168666,  2115.07720306,
#         2241.22,  1780.16,   748.82,  1627.26,   460.34,   503.45,
#          504.63,  1467.65,   462.77,   814.27,   720.7 ,  1808.07,
#          216.58,  2239.73,   823.05,  1628.58,  2470.53,  1634.05,
#         2433.27,  2125.54,  1324.9 ,   801.59,   738.16,  1476.76,
#          214.64,   813.15,  1139.61,   218.82,  1333.42,  2436.08,
#         1925.99,  1801.74,  2262.51,   199.09,   464.01,  1018.55,
#          504.92,  1862.39,   198.88,  1929.21,   198.28,   504.45,
#         1637.05,  1273.42,   462.06,  1459.44,   460.82,  2119.13,
#          503.73,   510.55,  1031.47,  2457.56,  1146.09,  1799.43,   750.28])
# array([ 1874.20354866,  2162.30628194,  2014.06998743,  2279.87701274,
#         2115.07720306,  1944.99461505,  2342.9978586 ,  1856.33077241,
#         2054.51147603,  1792.13715627,  2342.9978586 ,  1874.20354866,
#         2489.35282452,  1792.13715627,  1874.20354866,  2171.97352083,
#         1856.33077241,  2115.07720306,  1792.13715627,  1549.35249409,
#         2342.9978586 ,  2208.62846267,  2018.46168666,  2333.48263302,
#         2342.9978586 ,  2054.51147603,  2333.48263302,  2171.97352083,
#         2018.46168666,  2115.07720306,  2427.63989851,  2333.48263302,
#         1549.35249409,  2208.62846267,  1874.20354866,  2115.07720306,
#         2342.9978586 ,  2162.30628194,  2489.35282452,  2115.07720306,
#         2171.97352083,  2489.35282452,  2427.63989851,  2333.48263302,
#         1710.75736949,  2333.48263302,  1856.33077241,  1792.13715627,
#         1856.33077241,  1874.20354866,  1549.35249409,  1944.99461505,
#         2014.06998743,  2054.51147603,  1861.75615312,  2535.15548196,
#         1944.99461505,  2054.51147603,  2535.15548196,  2279.87701274,
#         2535.15548196,  2279.87701274,  2171.97352083,  1710.75736949,
#         2014.06998743,  2162.30628194,  1856.33077241,  1710.75736949,
#         2162.30628194,  1861.75615312,  2115.07720306,  2489.35282452,
#         2333.48263302,  2279.87701274,  2427.63989851,  1861.75615312,
#         1861.75615312,  1874.20354866,  1861.75615312,  2279.87701274,
#         1549.35249409,  2342.9978586 ,  1549.35249409,  1549.35249409,
#         2054.51147603,  2171.97352083,  1792.13715627,  2162.30628194,
#         1792.13715627,  2054.51147603,  1861.75615312,  1856.33077241,
#         2171.97352083,  2208.62846267,  2162.30628194,  2279.87701274,
#         2018.46168666])
# 【【】】adding new model for BC.pickle
#
# ____________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-73d67ff4a036> in <module>()
# ----> 1 t_gb = wrapper([ GradientBoostingCVModel ])
#
# <ipython-input-3-2005d6e813e1> in wrapper(functionList)
#      13             print()
#      14             for filename in filenames:
# ---> 15                 out = f(filename)
#      16                 newScore = out[filename]['train_rmse_cv_picking']
#      17
#
# /data/home/a1singh/IPPD/IPPD/workbench/allfunctions.py in GradientBoostingCVModel(filename, scale)
#     191
#     192
# --> 193     with open(filename, 'rb') as handle:
#     194         data = pickle.load(handle)
#     195
#
# FileNotFoundError: [Errno 2] No such file or directory: 'CD.pickle'

# %%
t_print = t_gb

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_gb
prefix = '4C2_' + 'gb'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:2])
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Random Forest

# %%
t_rf = wrapper([ RandomForestCVModel ])

# %%
t_print = t_rf

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_rf
prefix = '4C2_' + 'rforest'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:2])
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Which features were given most weights by each model ?
