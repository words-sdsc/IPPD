# %%
# import all the filenames
from allfunctions import *

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 7  def SVRPolyCVModel(filename):
#
# 8  def SVRSigmoidCVModel(filename):
#
# 9  def SVRLinearCVModel(filename):
#
# 10 def SVRRbfCVModel(filename):

# %%
def wrapper(functionList = []):
    if __name__ == '__main__':
        
        #functionList = [ SVRPolyCVModel, SVRSigmoidCVModel, SVRLinearCVModel, SVRRbfCVModel]

        filenames = ['AB.pickle', 'BC.pickle', 'CD.pickle', 'AC.pickle', 'AD.pickle', 'BD.pickle' ]
        
        model_selection = {}
        
        for f in functionList:
            print()
            for filename in filenames:
                out = f(filename)
                newScore = out[filename]['train_rmse_cv_picking']

                if filename in model_selection:
                    
                    #compare scores and select more accurate model
                    oldScore = model_selection[filename]['train_rmse_cv_picking']
                    if(newScore < oldScore):
                        print("【【【】】】switching models for %s..." % filename)
                        print("【【【】】】newScore: %f < oldScore: %f" % (newScore, oldScore))
                        print("【【【】】】newModel: %s \n" % f)
                        print(100*'_')
                        model_selection[filename] = out[filename]
                else:
                    
                    #no score to compare
                    print("【【】】adding new model for %s \n" % filename)
                    print(100*'_')
                    model_selection[filename] = out[filename]
    return model_selection

# %% [markdown]
# # Linear kernel

# %%
t_SVRLinearCVModel = wrapper([ SVRLinearCVModel ])
# Out:
# Dataset size read: train 127 and test 194
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)
#
#  Best parameters set found on development set:
#
# {'coef0': 0.0, 'degree': 3, 'epsilon': 50, 'C': 100000.0, 'gamma': 1.0}
# SVR(C=100000.0, cache_size=20480, coef0=0.0, degree=3, epsilon=50, gamma=1.0,
#   kernel='linear', max_iter=-1, shrinking=False, tol=1e-07, verbose=False)
#
# Full Test Set: 194
# array([  692.62,  2828.23,  1031.47,  1799.43,  1076.1 ,  1332.56,
#         1366.43,  2543.24,   510.55,   503.73,  1623.84,  1082.16,
#          198.88,   644.52,   215.55,  1001.19,  2127.71,   197.88,
#         2683.3 ,  2087.18,   322.27,   323.21,  2681.79,  1688.66,
#         2230.04,   750.28,  3621.04,  1462.69,   801.4 ,  2442.42,
#          998.83,  2258.66,  3059.32,  2089.36,  1873.73,  2125.54,
#          996.42,  2457.56,  1881.93,   297.21,  3143.72,   643.53,
#         1324.9 ,  1862.39,  3200.82,   298.03,  2433.27,  1080.  ,
#          462.77,   460.34,   460.82,  2684.27,  1870.14,  1458.18,
#         2270.37,  1273.42,  2659.86,   504.92,  2265.29,  2106.02,
#          298.64,  2436.08,   747.33,   689.4 ,  2833.87,  1139.61,
#         1036.77,  1467.65,   640.49,  1358.2 ,  1476.76,  2470.53,
#         1727.59,  2123.49,  1472.6 ,  2129.21,  1467.78,  1357.24,
#          216.58,  1627.26,  2836.53,   695.76,   323.32,  2832.66,
#         1134.68,   720.7 ,  1801.74,  2119.13,  1466.25,  1637.05,
#          218.82,  1628.58,  1333.42,  1459.44,  1037.79,   322.13,
#         1634.05,   746.49,  1808.07,   462.06,  2262.51,  1365.13,
#          998.65,  1037.18,  2271.12,   738.16,  2451.8 ,   814.27,
#         1141.32,   199.09,  2241.22,  1929.21,  2142.12,  1806.17,
#          214.64,   504.45,   464.01,  1036.27,  1146.09,  2239.73,
#         1333.76,  1792.62,   813.15,   505.67,  2450.37,  1469.66,
#         1135.84,   198.71,   216.71,   198.45,  2453.84,  1925.99,
#         1802.26,  1944.16,   810.75,  1959.63,  1018.55,   503.45,
#          748.82,  1780.16,  2478.78,  1135.23,  1471.89,   504.63,   801.59])
# array([-33668739.45328456, -74154973.59390956, -47161790.90640956,
#        -60683440.75015956, -33683178.56265956, -60654842.50015956,
#        -47190275.32828456, -74190537.45328456, -60647762.67203456,
#        -74190537.45328456, -33640421.12515956, -33675819.10953456,
#        -60661921.96890956, -60676081.32828456, -47140552.25015956,
#        -74140814.40640956, -74147893.73453456, -47140552.25015956,
#        -33661659.84390956, -74147893.73453456, -60640683.34390956,
#        -47183309.62515956, -60683440.75015956, -74183571.75015956,
#        -33661659.84390956, -33683178.56265956, -47147631.60953456,
#        -33640421.12515956, -33675819.10953456, -60669001.60953456,
#        -33668739.45328456, -47161790.90640956, -60661921.96890956,
#        -60640683.34390956, -74147893.73453456, -33647500.54703456,
#        -33661659.84390956, -33690144.20328456, -33654580.31265956,
#        -33668739.45328456, -60676081.32828456, -74154973.59390956,
#        -47147631.60953456, -47154711.37515956, -33690144.20328456,
#        -47154711.37515956, -74162053.06265956, -60661921.96890956,
#        -47168870.51578456, -74154973.59390956, -74176212.42203456,
#        -47154711.37515956, -74183571.75015956, -74140814.40640956,
#        -60669001.60953456, -60676081.32828456, -74176212.42203456,
#        -47190275.32828456, -47190275.32828456, -74176212.42203456,
#        -74169132.73453456, -33690144.20328456, -74140814.40640956,
#        -60647762.67203456, -60647762.67203456, -60654842.50015956,
#        -60690406.39078456, -47183309.62515956, -33683178.56265956,
#        -74169132.73453456, -60669001.60953456, -60640683.34390956,
#        -74162053.06265956, -60654842.50015956, -47175950.26578456,
#        -47183309.62515956, -33640421.12515956, -47161790.90640956,
#        -47168870.51578456, -74190537.45328456, -60690406.39078456,
#        -60690406.39078456, -33640421.12515956, -33647500.54703456,
#        -33654580.31265956, -33647500.54703456, -33675819.10953456,
#        -47147631.60953456, -47168870.51578456, -74183571.75015956,
#        -47175950.26578456, -33654580.31265956, -47140552.25015956,
#        -74169132.73453456, -74162053.06265956, -60683440.75015956,
#        -47175950.26578456])
# 【【】】adding new model for AB.pickle
#
# ____________________________________________________________________________________________________
# Dataset size read: train 192 and test 129
#
# # Tuning hyper-parameters
#
# Starting grdsurch.fit(X_train, y_train)

# %%
t_print = t_SVRLinearCVModel

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_SVRLinearCVModel
prefix = '4C2_' + 'SVRLinearCVModel'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:2]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Sigmoid Kernel

# %%
t_svr_sig = wrapper([ SVRSigmoidCVModel ])

# %%
t_print = t_svr_sig

for key in t_print.keys():
    print(80*'_')
    print(key)    

    print('Model: %s' % (str(t_print[key]['model'])[:20]))
    print('Train RMSE: %f \n' % (t_print[key]['train_rmse_cv_picking']))

    #print('Test RMSE   : %f' % (t_print[key]['test_rmse_reporting']))
    #print('Overall Mean: %f \n' % (t_print[key]['test_mean_y_comparing']))

    if(not t_print[key]['test_rmse_reportingA']==None):
        print('A...TestA RMSE   : %f' % float(t_print[key]['test_rmse_reportingA'] or -1))
        print('A...<<y_test_A Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingA'] or -1))

    if(not t_print[key]['test_rmse_reportingB']==None):
        print('B...TestB RMSE   : %f' % float(t_print[key]['test_rmse_reportingB'] or -1))
        print('B...<<y_test_B Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingB'] or -1))

    if(not t_print[key]['test_rmse_reportingC']==None):
        print('C...TestC RMSE   : %f' % float(t_print[key]['test_rmse_reportingC'] or -1))
        print('C...<<y_test_C Mean>>: %f \n' % float(t_print[key]['test_mean_y_comparingC'] or -1))

    if(not t_print[key]['test_rmse_reportingD']==None):
        print('D...TestD RMSE   : %f' % float(t_print[key]['test_rmse_reportingD'] or -1))
        print('D...<<y_test_D Mean>>: %f' % float(t_print[key]['test_mean_y_comparingD'] or -1))

    print(80*'_')

# %%
# write the model
import pickle

#||||||||||||||||||| 
t_ = t_svr_sig
prefix = '4C2_' + 'svr_sig'
#||||||||||||||||||| 

for k in t_.keys():
    mo   = t_[k]['model']
    fname = prefix + '_tuned_' + str(k[:2]) + '.pickle'
    
    print()
    print(k, str(mo)[:30])
    
    print(fname)
    # write the model to a file
    with open(fname, 'wb') as handle:
        pickle.dump(mo, handle)

# %% [markdown]
# # Poly kernel

# %%
t_SSVRPolyCVModel = wrapper([ SVRPolyCVModel ])

# %% [markdown]
# # Which features were given most weights by each model ?
